# %% [markdown]
# ANALISE DE DADOS PUBLICOS

# %% [markdown]
# COMPARATIVO DE FAIXA ETARIA E GRAU DE ESCOLARIDADE DOS ELEITORES DA CIDADE DE SJC.

# %% [markdown]
# Pandas é a biblioteca que carrego na memória com um apelido pd

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
pd.options.display.max_columns = 60
plt.rcParams['figure.figsize'] = (10,7)

# %% [markdown]
# Efetuado a alteração da variavel que carrega o caminho do arquivo pd para fx (variavel filtrara os dados da Cidade de SJC.)

# %%
pd = pd.read_csv(r'C:\Users\Rita\perfil_eleitorado_2020.csv', sep = ";", error_bad_lines=False, encoding= "Latin 1")
fx=pd.query("NM_MUNICIPIO =='SÃO JOSÉ DOS CAMPOS'")

# %% [markdown]
# Breve descrição dos campos referente tabela utilizada para uso das informações

# %% [markdown]
# DS_FAIXA_ETARIA = Descrição da faixa etaria a qual pertence o eleitor

# %% [markdown]
# NM_MUNICIPIO = Nome do município onde vota o eleitor

# %% [markdown]
# QT_ELEITORES_PERFIL = Quantidade de Eleitores aptos a votar

# %% [markdown]
# DS_GRAU_ESCOLARIDADE = Descrição do grau de escolaridade declarada pelo eleitor

# %%
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1101 entries, 24860 to 663439
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DT_GERACAO                  1101 non-null   object
#  1   HH_GERACAO                  1101 non-null   object
#  2   ANO_ELEICAO                 1101 non-null   int64
#  3   SG_UF                       1101 non-null   object
#  4   CD_MUNICIPIO                1101 non-null   int64
#  5   NM_MUNICIPIO                1101 non-null   object
#  6   CD_MUN_SIT_BIOMETRIA        1101 non-null   int64
#  7   DS_MUN_SIT_BIOMETRIA        1101 non-null   object
#  8   NR_ZONA                     1101 non-null   int64
#  9   CD_GENERO                   1101 non-null   int64
#  10  DS_GENERO                   1101 non-null   object
#  11  CD_ESTADO_CIVIL             1101 non-null   int64
#  12  DS_ESTADO_CIVIL             1101 non-null   object
# ...

# %%
fx.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 29108   10/09/2020   23:04:11         2020    SP         70998
# 30552   10/09/2020   23:04:11         2020    SP         70998
# 661949  10/09/2020   23:04:11         2020    SP         70998
# 30523   10/09/2020   23:04:11         2020    SP         70998
# 29125   10/09/2020   23:04:11         2020    SP         70998
# 24865   10/09/2020   23:04:11         2020    SP         70998
# 26303   10/09/2020   23:04:11         2020    SP         70998
# 40546   10/09/2020   23:04:11         2020    SP         70998
# 33444   10/09/2020   23:04:11         2020    SP         70998
# 26229   10/09/2020   23:04:11         2020    SP         70998
#
#                NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 29108   SÃO JOSÉ DOS CAMPOS                     0        Sem biometria
# 30552   SÃO JOSÉ DOS CAMPOS                     0        Sem biometria
# ...

# %% [markdown]
# Grafico abaixo mostra um comparativo da idade dos eleitores da cidade de são jose dos Campos.
# Atribuido a variavel fx o campos DS_FAIXA_ETARIA.

# %%
fx.groupby("DS_FAIXA_ETARIA").size().sort_values().plot(kind='barh', title='Comparativo dos eleitores de SJC que sao ')
# Out:
# <AxesSubplot:title={'center':'Comparativo dos eleitores de SJC que sao '}, ylabel='DS_FAIXA_ETARIA'>

# %%
fx.query('DS_FAIXA_ETARIA >= "18" and DS_FAIXA_ETARIA <= "70"')
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 24861   10/09/2020   23:04:11         2020    SP         70998
# 24862   10/09/2020   23:04:11         2020    SP         70998
# 24863   10/09/2020   23:04:11         2020    SP         70998
# 26224   10/09/2020   23:04:11         2020    SP         70998
# 26225   10/09/2020   23:04:11         2020    SP         70998
# ...            ...        ...          ...   ...           ...
# 663404  10/09/2020   23:04:11         2020    SP         70998
# 663405  10/09/2020   23:04:11         2020    SP         70998
# 663406  10/09/2020   23:04:11         2020    SP         70998
# 663407  10/09/2020   23:04:11         2020    SP         70998
# 663408  10/09/2020   23:04:11         2020    SP         70998
#
#                NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 24861   SÃO JOSÉ DOS CAMPOS                     0        Sem biometria
# ...

# %%
fx.groupby('DS_FAIXA_ETARIA')['QT_ELEITORES_PERFIL'].size()
# Out:
# DS_FAIXA_ETARIA
# 100 anos ou mais                  19
# 16 anos                            5
# 17 anos                           12
# 18 anos                           13
# 19 anos                           17
# 20 anos                           21
# 21 a 24 anos                      38
# 25 a 29 anos                      47
# 30 a 34 anos                      58
# 35 a 39 anos                      69
# 40 a 44 anos                      79
# 45 a 49 anos                      85
# 50 a 54 anos                      89
# 55 a 59 anos                      80
# 60 a 64 anos                      73
# 65 a 69 anos                      72
# 70 a 74 anos                      71
# 75 a 79 anos                      67
# 80 a 84 anos                      62
# 85 a 89 anos                      55
# 90 a 94 anos                      39
# 95 a 99 anos                      30
# Name: QT_ELEITORES_PERFIL, dtype: int64

# %%
fx.groupby('DS_GRAU_ESCOLARIDADE').size().sort_values().plot(kind='barh',title = 'Grau de Escolaridade dos Eleitores')
# Out:
# <AxesSubplot:title={'center':'Grau de Escolaridade dos Eleitores'}, ylabel='DS_GRAU_ESCOLARIDADE'>

# %%
fx.groupby('CD_GRAU_ESCOLARIDADE').size().sort_values().plot(kind='barh',title = 'Grau de Escolaridade dos Eleitores')
# Out:
# <AxesSubplot:title={'center':'Grau de Escolaridade dos Eleitores'}, ylabel='CD_GRAU_ESCOLARIDADE'>
